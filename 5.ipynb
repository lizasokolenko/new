# %% [markdown]
# Делаем список прилагательных, для которых в пару нет существительных.

# %%
line = ['тонкий', 'олений', 'белый', 'нежный', 'сухой', 'яичный', 'желтый', 'овечий', 'толстый', 'древесный', 'верхний', 'смуглый', 'твердый', 'гладкий', 'гусиный', 'серый', 'тигровый', 'мягкий', 'зеленый', 'красный', 'искусственный', 'грубый', 'старый', 'темный', 'картофельный', 'розовый', 'козий', 'крокодиловый', 'натуральный', 'золотистый', 'шагреневый', 'прозрачный', 'новый', 'чувствительный', 'бледный', 'луковый', 'чужой', 'блестящий', 'дряблый', 'матовый', 'бычий', 'хороший', 'львиный', 'последний', 'светлый', 'румяный', 'теплый', 'лисий', 'жесткий', 'морщинистый', 'золотой', 'шершавый', 'моржовый', 'молодой', 'проблемный', 'загорелый', 'атласный', 'тисненый', 'серебряный', 'океанический', 'лошадиный', 'бурый', 'континентальный', 'серебристый', 'пустой', 'влажный', 'чистый', 'сморщенный', 'тюлений', 'натянутый', 'дорогой', 'настоящий', 'мокрый', 'прочный', 'стеклянный', 'словесный', 'козлиный', 'свежий', 'синий', 'мертвый', 'нерпичий', 'еловый', 'дынный', 'беличий', 'красивый', 'лишний', 'желтоватый', 'каменный', 'осиновый', 'заячий', 'нижний', 'наружный', 'лосиный', 'оранжевый', 'холодный', 'грязный', 'мелкий', 'шелковистый', 'любой', 'пушистый', 'горячий', 'бычачий', 'ослиный', 'зеленоватый', 'шероховатый', 'бобровый', 'нормальный', 'лакированный', 'здоровый', 'бронзовый', 'упругий', 'потный', 'рыжий', 'ивовый', 'снежный', 'ржаной', 'лаковый', 'верблюжий', 'внешний', 'тугой', 'пестрый', 'крупный', 'хинный', 'конский', 'железный', 'драгоценный', 'драконий', 'кошачий', 'красноватый', 'яблочный', 'лайковый', 'потертый', 'обветренный', 'скользкий', 'шелковый', 'снятой', 'легкий', 'хрупкий', 'высохший', 'колючий', 'детский', 'эластичный', 'прекрасный', 'глянцевитый', 'лучший', 'синеватый', 'сплошной', 'обнаженный', 'целый', 'буйволовый', 'пупырчатый', 'слоновый', 'соленый', 'разноцветный', 'русский', 'веснушчатый', 'заскорузлый', 'обычный', 'нечистый', 'глянцевый', 'вялый', 'разный', 'тусклый', 'чешуйчатый', 'немецкий', 'нездоровый', 'облезлый', 'горелый', 'невыделанный', 'колбасный', 'луковичный', 'дефектный', 'пятнистый', 'солевой', 'почечный', 'меховой', 'клопиный', 'гнилой', 'воспаленный', 'рваный', 'светящийся', 'старческий', 'непроницаемый', 'прелый', 'козловый', 'мохнатый', 'чудесный', 'оливковый', 'обтянутый', 'рысий', 'розоватый', 'липкий', 'носорожий', 'белесый', 'малиновый', 'ветхий', 'сероватый', 'рисовый', 'шоколадный', 'сочный', 'маленький', 'лунный', 'материковый', 'известковый', 'огромный', 'стальной', 'ненужный', 'продажный', 'песцовый', 'куний', 'тертый', 'юношеский', 'сафьяновый', 'длинный', 'атласистый', 'огуречный', 'холеный', 'гибкий', 'тоненький', 'турецкий', 'сверкающий', 'тесный', 'худой', 'молочный', 'слоновий', 'иссохший', 'вкусный', 'пыльный', 'цельный', 'технический', 'бумажный', 'горький', 'аппетитный', 'мшистый', 'родной', 'глиняный', 'заплесневелый', 'хрусткий', 'броневой', 'русалочий', 'пыжиковый', 'отличный', 'добротный', 'комбинированный', 'крокодилий', 'жабий', 'мужской', 'привычный', 'неровный', 'усталый', 'наносный', 'огрубелый', 'раздраженный', 'ухоженный', 'замечательный', 'великолепный', 'небольшой', 'тончайший', 'зрелый', 'кофейный', 'жидкий', 'куриный', 'исподний', 'окровавленный', 'дельфиний', 'обезьяний', 'седельный', 'золоченый', 'стертый', 'замшевый', 'лишенный', 'белоснежный', 'неповрежденный', 'гранитный', 'зрительный', 'височный', 'кокосовый', 'столетний', 'вишневый', 'лохматый', 'кровавый', 'океанский', 'кровяной', 'защитный', 'роговой', 'ничтожный', 'соляный', 'рачий', 'гречневый', 'ценный', 'турий', 'кроличий', 'наждачный']

# %% [markdown]
# Список сверху сокращен (убраны прилагательные с суммарной частотностью меньше 4)

# %% [markdown]
# Проделываем то же, что и с существительными в третьей программе.
# Переменная dic должна содержать словарь частотности прилагательных каждого слова.

# %%
dic={}
line_dic={}
for word in dic:
    for l in line:
        if word == l:
            line_dic[l]=dic[word]
            print (word, dic[word])
print(line_dic)
# Out:
# {}

# %% [markdown]
# Добавляем слова, частотность которых 0, и заполняем таблицу для прилагательных отдельно ниже.

# %%
new_dic={}
for li in line:
    if li not in line_dic.keys():
        new_dic[li]=0
    else:
        new_dic[li]=line_dic[li]
for el in new_dic.items():
    print(el[1])
